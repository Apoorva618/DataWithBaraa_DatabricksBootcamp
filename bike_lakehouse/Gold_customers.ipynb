# %%
## This is the step where we do data modelling ( STAR schema, Snowflake schema, or create flat tables) 
# Read from silver table(s) 
# do business transformation and modeling 
#write it to gold table
